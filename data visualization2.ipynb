# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_can = pd.read_excel('canada.xlsx')

# %%
df_can.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'], axis=1, inplace=True)
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent','RegName':'Region'}, inplace=True)
df_can.columns = list(map(str, df_can.columns))
df_can.set_index('Country', inplace=True)
df_can['Total']=df_can.sum(axis=1)
years = list(map(str, range(1980, 2014)))
print('data dimensions:', df_can.shape)
# Out:
# data dimensions: (43, 38)

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_continents = df_can.groupby('Continent',axis=0).sum()
df_continents.head()
# Out:
#                                  1980  1981  1982  1983  1984  1985  1986  \
# Continent
# Africa                            111    85   110    90   102    77   117
# Asia                             5313  6832  3468  2027  1710  2262  2962
# Europe                            770   798   732   447   321   370   429
# Latin America and the Caribbean  2564  2554  2690  1782  1776  1621  1816
# Northern America                    0     0     0     0     0     0     0
#
#                                  1987  1988  1989  ...   2005   2006   2007  \
# Continent                                          ...
# Africa                            194   322   550  ...   5665   6701   5956
# Asia                             3919  4190  5886  ...  51915  42295  34782
# Europe                            602   576   622  ...   4252   3336   3113
# Latin America and the Caribbean  3279  2651  3201  ...   9438   9579   8837
# Northern America                    0     0     0  ...      0      0      0
#
#                                   2008   2009   2010   2011   2012   2013  \
# Continent
# Africa                            6383   7976   7884   7282   8016   8483
# Asia                             36735  35690  39679  36479  40829  41802
# Europe                            2686   2577   2210   1817   1974   1951
# Latin America and the Caribbean   9113   8662   9197   6771   6480   6359
# Northern America                     0      0      0      1      1      2
#
#                                   Total
# Continent
# Africa                           105258
# Asia                             813228
# Europe                            84601
# Latin America and the Caribbean  160191
# Northern America                     20
#
# [5 rows x 35 columns]

# %%
# autopct create %, start angle represent starting point
df_continents['Total'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )

plt.title('Immigration to Canada by Continent [1980 - 2013]')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.

df_continents['Total'].plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 continents
                            )

plt.title('Immigration to Canada by Continent [1980 - 2013]', y=1.12) 

plt.axis('equal') 

plt.legend(labels=df_continents.index, loc='upper left') 

plt.show()
plt.savefig("Immigration_to_Canada_by_Continent", bbox_inches = "tight", dip = 1200)

# %%
df_can
# Out:
#                                                                       Continent  \
# Country
# Afghanistan                                                                Asia
# Albania                                                                  Europe
# Algeria                                                                  Africa
# American Samoa                                                          Oceania
# Andorra                                                                  Europe
# Angola                                                                   Africa
# Antigua and Barbuda                             Latin America and the Caribbean
# Argentina                                       Latin America and the Caribbean
# Armenia                                                                    Asia
# Australia                                                               Oceania
# Austria                                                                  Europe
# Azerbaijan                                                                 Asia
# Bahamas                                         Latin America and the Caribbean
# Bahrain                                                                    Asia
# Bangladesh                                                                 Asia
# Barbados                                        Latin America and the Caribbean
# Belarus                                                                  Europe
# Belgium                                                                  Europe
# Belize                                          Latin America and the Caribbean
# Benin                                                                    Africa
# Bhutan                                                                     Asia
# Bolivia (Plurinational State of)                Latin America and the Caribbean
# Bosnia and Herzegovina                                                   Europe
# Botswana                                                                 Africa
# Brazil                                          Latin America and the Caribbean
# Brunei Darussalam                                                          Asia
# Bulgaria                                                                 Europe
# Burkina Faso                                                             Africa
# Burundi                                                                  Africa
# Cabo Verde                                                               Africa
# Cambodia                                                                   Asia
# Cameroon                                                                 Africa
# Canada                                                         Northern America
# Central African Republic                                                 Africa
# Chad                                                                     Africa
# Chile                                           Latin America and the Caribbean
# China                                                                      Asia
# China, Hong Kong Special Administrative Region                             Asia
# China, Macao Special Administrative Region                                 Asia
# Colombia                                        Latin America and the Caribbean
# Comoros                                                                  Africa
# Congo                                                                    Africa
# Costa Rica                                      Latin America and the Caribbean
#
#                                                                    Region  \
# Country
# Afghanistan                                                 Southern Asia
# Albania                                                   Southern Europe
# Algeria                                                   Northern Africa
# American Samoa                                                  Polynesia
# Andorra                                                   Southern Europe
# Angola                                                      Middle Africa
# Antigua and Barbuda                                             Caribbean
# Argentina                                                   South America
# Armenia                                                      Western Asia
# Australia                                       Australia and New Zealand
# Austria                                                    Western Europe
# Azerbaijan                                                   Western Asia
# Bahamas                                                         Caribbean
# Bahrain                                                      Western Asia
# Bangladesh                                                  Southern Asia
# Barbados                                                        Caribbean
# Belarus                                                    Eastern Europe
# Belgium                                                    Western Europe
# Belize                                                    Central America
# Benin                                                      Western Africa
# Bhutan                                                      Southern Asia
# Bolivia (Plurinational State of)                            South America
# Bosnia and Herzegovina                                    Southern Europe
# Botswana                                                  Southern Africa
# Brazil                                                      South America
# Brunei Darussalam                                      South-Eastern Asia
# Bulgaria                                                   Eastern Europe
# Burkina Faso                                               Western Africa
# Burundi                                                    Eastern Africa
# Cabo Verde                                                 Western Africa
# Cambodia                                               South-Eastern Asia
# Cameroon                                                    Middle Africa
# Canada                                                   Northern America
# Central African Republic                                    Middle Africa
# Chad                                                        Middle Africa
# Chile                                                       South America
# China                                                        Eastern Asia
# China, Hong Kong Special Administrative Region               Eastern Asia
# China, Macao Special Administrative Region                   Eastern Asia
# Colombia                                                    South America
# Comoros                                                    Eastern Africa
# Congo                                                       Middle Africa
# Costa Rica                                                Central America
#
#                                                            DevName  1980  \
# Country
# Afghanistan                                     Developing regions    16
# Albania                                          Developed regions     1
# Algeria                                         Developing regions    80
# American Samoa                                  Developing regions     0
# Andorra                                          Developed regions     0
# Angola                                          Developing regions     1
# Antigua and Barbuda                             Developing regions     0
# Argentina                                       Developing regions   368
# Armenia                                         Developing regions     0
# Australia                                        Developed regions   702
# Austria                                          Developed regions   234
# Azerbaijan                                      Developing regions     0
# Bahamas                                         Developing regions    26
# Bahrain                                         Developing regions     0
# Bangladesh                                      Developing regions    83
# Barbados                                        Developing regions   372
# Belarus                                          Developed regions     0
# Belgium                                          Developed regions   511
# Belize                                          Developing regions    16
# Benin                                           Developing regions     2
# Bhutan                                          Developing regions     0
# Bolivia (Plurinational State of)                Developing regions    44
# Bosnia and Herzegovina                           Developed regions     0
# Botswana                                        Developing regions    10
# Brazil                                          Developing regions   211
# Brunei Darussalam                               Developing regions    79
# Bulgaria                                         Developed regions    24
# Burkina Faso                                    Developing regions     2
# Burundi                                         Developing regions     0
# Cabo Verde                                      Developing regions     1
# Cambodia                                        Developing regions    12
# Cameroon                                        Developing regions     9
# Canada                                           Developed regions     0
# Central African Republic                        Developing regions     4
# Chad                                            Developing regions     0
# Chile                                           Developing regions  1233
# China                                           Developing regions  5123
# China, Hong Kong Special Administrative Region  Developing regions     0
# China, Macao Special Administrative Region      Developing regions     0
# Colombia                                        Developing regions   266
# Comoros                                         Developing regions     0
# Congo                                           Developing regions     2
# Costa Rica                                      Developing regions    28
#
#                                                 1981  1982  1983  1984  1985  \
# Country
# Afghanistan                                       39    39    47    71   340
# Albania                                            0     0     0     0     0
# Algeria                                           67    71    69    63    44
# American Samoa                                     1     0     0     0     0
# Andorra                                            0     0     0     0     0
# Angola                                             3     6     6     4     3
# Antigua and Barbuda                                0     0     0    42    52
# Argentina                                        426   626   241   237   196
# Armenia                                            0     0     0     0     0
# Australia                                        639   484   317   317   319
# Austria                                          238   201   117   127   165
# Azerbaijan                                         0     0     0     0     0
# Bahamas                                           23    38    12    21    28
# Bahrain                                            2     1     1     1     3
# Bangladesh                                        84    86    81    98    92
# Barbados                                         376   299   244   265   285
# Belarus                                            0     0     0     0     0
# Belgium                                          540   519   297   183   181
# Belize                                            27    13    21    37    26
# Benin                                              5     4     3     4     3
# Bhutan                                             0     0     0     1     0
# Bolivia (Plurinational State of)                  52    42    49    38    44
# Bosnia and Herzegovina                             0     0     0     0     0
# Botswana                                           1     3     3     7     4
# Brazil                                           220   192   139   145   130
# Brunei Darussalam                                  6     8     2     2     4
# Bulgaria                                          20    12    33    11    24
# Burkina Faso                                       1     3     2     3     2
# Burundi                                            0     0     0     1     2
# Cabo Verde                                         1     2     0    11     1
# Cambodia                                          19    26    33    10     7
# Cameroon                                           2    16     7     8    13
# Canada                                             0     0     0     0     0
# Central African Republic                           3     1     0     0     0
# Chad                                               0     1     0     0     1
# Chile                                           1069  1078   781   681   533
# China                                           6682  3308  1863  1527  1816
# China, Hong Kong Special Administrative Region     0     0     0     0     0
# China, Macao Special Administrative Region         0     0     0     0     0
# Colombia                                         326   360   244   235   214
# Comoros                                            2     2     0     0     2
# Congo                                              0     1     0     1     2
# Costa Rica                                        35    42    51    75   113
#
#                                                 1986  ...   2005   2006  \
# Country                                               ...
# Afghanistan                                      496  ...   3436   3009
# Albania                                            1  ...   1223    856
# Algeria                                           69  ...   3626   4807
# American Samoa                                     0  ...      0      1
# Andorra                                            2  ...      0      1
# Angola                                             5  ...    295    184
# Antigua and Barbuda                               51  ...     24     32
# Argentina                                        213  ...   1153    847
# Armenia                                            0  ...    224    218
# Australia                                        356  ...    909    875
# Austria                                          196  ...    122    102
# Azerbaijan                                         0  ...    359    236
# Bahamas                                           23  ...     14     18
# Bahrain                                            0  ...     12     12
# Bangladesh                                       486  ...   4171   4014
# Barbados                                         251  ...    111     97
# Belarus                                            0  ...    558    439
# Belgium                                          197  ...    400    302
# Belize                                            25  ...     37     24
# Benin                                              6  ...     95    116
# Bhutan                                             0  ...      5     10
# Bolivia (Plurinational State of)                  79  ...    134    139
# Bosnia and Herzegovina                             0  ...    211    217
# Botswana                                           2  ...      7     11
# Brazil                                           205  ...    969   1181
# Brunei Darussalam                                 12  ...      4      5
# Bulgaria                                          33  ...   1738   1419
# Burkina Faso                                       7  ...     91    147
# Burundi                                            1  ...    626    468
# Cabo Verde                                         9  ...      5      7
# Cambodia                                           8  ...    370    529
# Cameroon                                          11  ...    604    697
# Canada                                             0  ...      0      0
# Central African Republic                           0  ...     49     18
# Chad                                               2  ...    126     96
# Chile                                            633  ...    384    427
# China                                           1960  ...  42584  33518
# China, Hong Kong Special Administrative Region     0  ...    729    712
# China, Macao Special Administrative Region         0  ...     21     32
# Colombia                                         257  ...   6424   6535
# Comoros                                            1  ...      5      7
# Congo                                              4  ...    136    143
# Costa Rica                                        79  ...    188    279
#
#                                                  2007   2008   2009   2010  \
# Country
# Afghanistan                                      2652   2111   1746   1758
# Albania                                           702    560    716    561
# Algeria                                          3623   4005   5393   4752
# American Samoa                                      0      0      0      0
# Andorra                                             1      0      0      0
# Angola                                            106     76     62     61
# Antigua and Barbuda                                15     32     38     27
# Argentina                                         620    540    467    459
# Armenia                                           198    205    267    252
# Australia                                        1033   1018   1018    933
# Austria                                            98     91    109    124
# Azerbaijan                                        203    125    165    209
# Bahamas                                            23     30     27     25
# Bahrain                                            22      9     35     28
# Bangladesh                                       2897   2939   2104   4721
# Barbados                                          130    134    125    121
# Belarus                                           568    524    454    438
# Belgium                                           363    335    358    363
# Belize                                             28     48     38     39
# Benin                                             183    205    238    290
# Bhutan                                              7     36    865   1464
# Bolivia (Plurinational State of)                  107    143    214    180
# Bosnia and Herzegovina                            209    182    156    168
# Botswana                                            8     28     15     42
# Brazil                                           1746   2138   2509   2598
# Brunei Darussalam                                  11     10      5     12
# Bulgaria                                         1172    994    784    556
# Burkina Faso                                      136    139    162    186
# Burundi                                           614    448    566    529
# Cabo Verde                                          2      5      1      3
# Cambodia                                          460    354    203    200
# Cameroon                                         1025   1279   1344   1800
# Canada                                              0      0      0      0
# Central African Republic                           30     28     19     26
# Chad                                              131     95     87     98
# Chile                                             530    350    375    340
# China                                           27642  30037  29622  30391
# China, Hong Kong Special Administrative Region    674    897    657    623
# China, Macao Special Administrative Region         16     12     21     21
# Colombia                                         5357   5452   4652   5218
# Comoros                                            11      3     19     22
# Congo                                              87     72     70     75
# Costa Rica                                        281    246    217    190
#
#                                                  2011   2012   2013   Total
# Country
# Afghanistan                                      2203   2635   2004   58639
# Albania                                           539    620    603   15699
# Algeria                                          4325   3774   4331   69439
# American Samoa                                      0      0      0       6
# Andorra                                             0      1      1      15
# Angola                                             39     70     45    2113
# Antigua and Barbuda                                37     51     25     981
# Argentina                                         278    263    282   19596
# Armenia                                           236    258    207    3310
# Australia                                         851    982   1121   23829
# Austria                                            84    102     90    4985
# Azerbaijan                                        138    161     57    2649
# Bahamas                                            40     60     55     808
# Bahrain                                            21     39     32     475
# Bangladesh                                       2694   2640   3789   65568
# Barbados                                           97    132     97    6923
# Belarus                                           357    277    247    7975
# Belgium                                           332    402    379   10762
# Belize                                             36     34     53    1083
# Benin                                             284    391    397    2852
# Bhutan                                           1879   1075    487    5876
# Bolivia (Plurinational State of)                   86     83    107    3205
# Bosnia and Herzegovina                            140    121    119   21855
# Botswana                                           53     64     76     396
# Brazil                                           1508   1642   1714   29659
# Brunei Darussalam                                   6      3      6     600
# Bulgaria                                          365    451    512   23310
# Burkina Faso                                      144    269    322    2043
# Burundi                                           604    684    480    8110
# Cabo Verde                                          3      6      2     201
# Cambodia                                          196    233    288    6538
# Cameroon                                         1638   2507   2439   16021
# Canada                                              1      1      2      20
# Central African Republic                           18     45    169     550
# Chad                                               79     97     86    1653
# Chile                                             174    291    273   21359
# China                                           28502  33024  34129  659962
# China, Hong Kong Special Administrative Region    591    728    774    9327
# China, Macao Special Administrative Region         13     33     29     284
# Colombia                                         4366   3741   3631   72088
# Comoros                                            14     18     22     194
# Congo                                              81     91    114    1686
# Costa Rica                                        149    183    122    4489
#
# [43 rows x 38 columns]

# %%
df_Algeria = df_can.loc[['Algeria'],years].transpose()
df_Algeria.head()
# Out:
# Country  Algeria
# 1980          80
# 1981          67
# 1982          71
# 1983          69
# 1984          63

# %%
df_total=pd.DataFrame(df_can[years].sum(axis=0))
df_total.index = map(int, df_total.index)
df_total.reset_index(inplace = True)
df_total.columns = ['year', 'total']
df_total.head(5)
# Out:
#    year  total
# 0  1980   9460
# 1  1981  10909
# 2  1982   7484
# 3  1983   4663
# 4  1984   4226

# %%
df_total.plot(
    kind='scatter',
    x='year',
    y='total'
)
plt.title('Total Immigrant Population to Canada from 1980-2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
x = df_total['year']
y=df_total['total']
fit = np.polyfit(x,y,deg=1)
fit
# Out:
# array([ 2.13309748e+03, -4.22381344e+06])

# %%
df_can.head(5)
# Out:
#                Continent           Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...  2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  3436  3009  2652  2111
# Albania            0     0     0     0     1  ...  1223   856   702   560
# Algeria           71    69    63    44    69  ...  3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...     0     1     0     0
# Andorra            0     0     0     0     2  ...     0     1     1     0
#
#                 2009  2010  2011  2012  2013  Total
# Country
# Afghanistan     1746  1758  2203  2635  2004  58639
# Albania          716   561   539   620   603  15699
# Algeria         5393  4752  4325  3774  4331  69439
# American Samoa     0     0     0     0     0      6
# Andorra            0     0     0     1     1     15
#
# [5 rows x 38 columns]

# %%
df_iceland.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Year') # add to x-label to the plot
plt.ylabel('Number of immigrants') # add y-label to the plot
plt.title('Icelandic immigrants to Canada from 1980 to 2013') # add title to the plot

plt.show()

# %%
df_iceland.plot(kind='bar', figsize=(10, 6), rot=90) # rotate the bars by 90 degrees

plt.xlabel('Year')
plt.ylabel('Number of Immigrants')
plt.title('Icelandic Immigrants to Canada from 1980 to 2013')

# Annotate arrow
plt.annotate('',                      # s: str. Will leave it blank for no text
             xy=(32, 70),             # place head of the arrow at point (year 2012 , pop 70)
             xytext=(28, 20),         # place base of the arrow at point (year 2008 , pop 20)
             xycoords='data',         # will use the coordinate system of the object being annotated 
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=2)
            )

plt.show()

# %%
df_can.sort_values(['Total'], ascending=False, axis=0, inplace=True)

# get the top 5 entries
df_top15 = df_can.head(15)

# transpose the dataframe
df_top15 = df_top15[years].transpose() 

df_top15.head()

# %%
df_top15.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Number of Immigrants')
plt.title('Top 15 Conuntries Contributing to the Immigration to Canada between 1980 - 2013')

for index, value in enumerate(df_top15): 
    label = format(int(value), ',') # format int with commas
    
    # place text at the end of bar (subtracting 47000 from x, and 0.1 from y to make it fit within the bar)
    plt.annotate(label, xy=(value - 47000, index - 0.10), color='white')
